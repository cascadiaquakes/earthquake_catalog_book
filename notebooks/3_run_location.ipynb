# %%
import os
import subprocess

# %% [markdown]
# # Run location using NonLinLoc
# using calls to NonLinLoc with previously generated config files to locate the earthquakes

# %%
confing_file = "nlloc_runfile_poly2.in"
os.makedirs("./loc",exist_ok=True)

# this line is specific to run NLL on linux subsystem on windows
cp = subprocess.run(["wsl",  "bash", "-ic", f"NLLoc ./NLL_config_files/{confing_file}"], capture_output=True)

# this is for unix based
# cp = subprocess.run([f"NLLoc ./NLL_config_files/{confing_file}"], capture_output=True, shell=True)

cp
# Out:
# CompletedProcess(args=['wsl', 'bash', '-ic', 'NLLoc ./NLL_config_files/nlloc_runfile_poly2.in'], returncode=0, stdout=b'NLLoc (NonLinLoc v7.1.02 09Feb2024) \n... Reading observation file ./nll_picks/NLL_picks.txt\nReading next set of observations (Files open: Tot:3 Buf:0 Hdr:0  Alloc: 0) ...\n... 24 observations read, 16 will be used for location (./loc/test_loc.20190712.190440_61500713).\nLocating... (Files open: Tot:3 Buf:0 Hdr:0  Alloc: 4016  3DMem: used:16/avail:20/load:16) ...\nOctTree num samples = 5000 / 100000\rOctTree num samples = 10000 / 100000\rOctTree num samples = 15000 / 100000\rOctTree num samples = 20000 / 100000\rOctTree num samples = 25000 / 100000\rOctTree num samples = 30000 / 100000\rOctTree num samples = 35000 / 100000\rOctTree num samples = 40000 / 100000\rOctTree num samples = 45000 / 100000\rOctTree num samples = 50000 / 100000\rOctTree num samples = 55000 / 100000\rOctTree num samples = 60000 / 100000\rOctTree num samples = 65000 / 100000\rOctTree num sampl
# ...
