# %% [markdown]
# # Visualization notebook
#
# Showcase some visualization examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data loading
#
# * processed data from previous notebook or here....

# %%
x = np.arange(10)
y = np.random.randint(0, 100, size=10)
y
# Out:
# array([42, 56,  4,  3, 31, 55, 36, 50, 70, 21])

# %% [markdown]
# ## Plots
# * plot 1 does...
# * plot 2 does...

# %%
plt.plot(x, y)
plt.title("plot 1: x y")
# Out:
# Text(0.5, 1.0, 'plot 1: x y')

# %%
plt.scatter(y, x)
plt.title("plot 2: scatter y x")
# Out:
# Text(0.5, 1.0, 'plot 2: scatter y x')
